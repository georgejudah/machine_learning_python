# %% [markdown]
# ### imports

# %%
import numpy as np
import tensorflow as tf
import keras
#keras is a bolt to tensorflow(but it has for other tech as well)
from IPython.core.display import display
from keras.applications.inception_resnet_v2 import InceptionResNetV2, decode_predictions, preprocess_input
# Used for executing the program

# %% [markdown]
# ### Constants

# %%
FILE_1 = '01 Umbrella.jpg'
FILE_2 = '02 Couple.jpg'
FILE_3 = '03 Ocean.jpg'

# %% [markdown]
# ### Preprocessing Images

# %%
pic = tf.keras.utils.load_img(FILE_1, target_size = (299, 299))
display(pic)
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
pic_array = tf.keras.utils.img_to_array(pic)
pic_array.shape
# Out:
# (299, 299, 3)

# %%
expanded = np.expand_dims(pic_array, axis = 0)
expanded.shape
# doing this for passing the array to the predict function
# Out:
# (1, 299, 299, 3)

# %%
preprocessed =  preprocess_input(expanded)

# %%
# %%time
inception_model = InceptionResNetV2(weights= 'imagenet')
# Out:
# Wall time: 5.26 s

# %% [markdown]
# #

# %% [markdown]
# # Making Predictions

# %%
predictions = inception_model.predict(preprocessed)
decode_predictions(predictions)
# Out:
# 1/1 [==============================] - 0s 191ms/step
# [[('n04507155', 'umbrella', 0.8298835),
#   ('n03788195', 'mosque', 0.0012544581),
#   ('n03792972', 'mountain_tent', 0.0012220597),
#   ('n03220513', 'dome', 0.0011231129),
#   ('n04479046', 'trench_coat', 0.0010624691)]]
